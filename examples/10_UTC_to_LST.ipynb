# %% [markdown]
# # Converting files named with UTC to LST
#
# In the previous example, we try to do everything in UTC. However, in order to explain the results more intuitively, LST is a better time framework to work with. In this example, we will convert original QPESUMS data from UTC to LST.

# %%
import os, logging, argparse, datetime, shutil
import numpy as np
import pandas as pd

def search_qpesums_npy(srcdir):
    '''Scan QPESUMS data in *.npy format (6*275*162) from the specified directory.
    '''
    import pandas as pd
    fileinfo = []
    for subdir, dirs, files in os.walk(srcdir, followlinks=True):
        for f in files:
            if f.endswith('.npy'):
                # Parse file name for time information
                furi = os.path.join(subdir, f)
                finfo = f.split('.')
                ftime = finfo[0]
                #logging.debug([furi] + finfo[1:3])
                fileinfo.append([furi, ftime])
    results = pd.DataFrame(fileinfo, columns=['furi', 'timestamp'])
    results = results.sort_values(by=['timestamp']).reset_index(drop=True)
    return(results)

def correct_qpesums_datetime(ts):
    '''Check the time-stamp string in the form of YYYY-mm-dd-HH:
         - if HH = 24, increment the dd by one and change HH to 00
    '''
    import datetime
    if ts[8:] == '24':
        oldt = datetime.datetime.strptime(ts[:8], '%Y%m%d')
        newt = oldt + datetime.timedelta(days=1)
    else:
        newt = datetime.datetime.strptime(ts, '%Y%m%d%H')
    return(newt)

def covert_utc_to_lst(tslist, time_zone=8):
    '''Convert a list of timestamps to the specified time zone (+8 by default).
    '''
    lst_list = []
    for t in tslist:
        t_utc = correct_qpesums_datetime(t)                     # Correct hour naming
        t_lst = t_utc + datetime.timedelta(hours=time_zone)     # Shift time zone
        lst_list.append(t_lst.strftime('%Y%m%d%H'))             # Convert to string
    return(lst_list)

def correct_qpesums_files(finfo, outdir):
    '''Copy the original QPESUMS data to the new directory with the corresponding timestamp in LST.
    '''
    for i in range(finfo.shape[0]):
        rec = finfo.iloc[i,:]
        newuri = os.path.join(outdir, rec['lst']+'.npy')
        logging.debug("Copying " + rec['furi'] + ' to ' + newuri)
        shutil.copy(rec['furi'], newuri)
    return(0)

# %%
# PARAMETERS
INPUT = 'D:\worksapce\qpetw\data\dbz_2014061316'
OUTPUT = 'D:\worksapce\qpetw\data\dbz_2014061316_LST'
# Set up logging
logging.basicConfig(level=logging.DEBUG)
# Scan files for reading
finfo = search_qpesums_npy(INPUT)
# Create LST timestamp
finfo['lst'] = covert_utc_to_lst(finfo.timestamp)
# Generate output
correct_qpesums_files(finfo, OUTPUT)
# Out:
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061301.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061309.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061302.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061310.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061303.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061311.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061304.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061312.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061305.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061313.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061306.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061314.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061307.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061315.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061308.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061316.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061309.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061317.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061310.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061318.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061311.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061319.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061312.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061320.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061313.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061321.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061314.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061322.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061315.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061323.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061316.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061400.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061317.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061401.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061318.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061402.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061319.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061403.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061320.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061404.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061321.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061405.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061322.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061406.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061323.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061407.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061324.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061408.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061401.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061409.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061402.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061410.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061403.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061411.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061404.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061412.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061405.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061413.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061406.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061414.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061407.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061415.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061408.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061416.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061409.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061417.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061410.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061418.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061411.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061419.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061412.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061420.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061413.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061421.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061414.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061422.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061415.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061423.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061416.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061500.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061417.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061501.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061418.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061502.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061419.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061503.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061420.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061504.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061421.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061505.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061422.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061506.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061423.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061507.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061424.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061508.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061501.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061509.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061502.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061510.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061503.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061511.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061504.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061512.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061505.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061513.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061506.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061514.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061507.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061515.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061508.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061516.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061509.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061517.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061510.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061518.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061511.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061519.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061512.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061520.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061513.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061521.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061514.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061522.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061515.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061523.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061516.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061600.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061517.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061601.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061518.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061602.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061519.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061603.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061520.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061604.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061521.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061605.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061522.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061606.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061523.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061607.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061524.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061608.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061601.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061609.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061602.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061610.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061603.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061611.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061604.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061612.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061605.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061613.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061606.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061614.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061607.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061615.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061608.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061616.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061609.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061617.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061610.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061618.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061611.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061619.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061612.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061620.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061613.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061621.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061614.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061622.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061615.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061623.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061616.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061700.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061617.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061701.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061618.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061702.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061619.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061703.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061620.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061704.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061621.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061705.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061622.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061706.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061623.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061707.npy
# DEBUG:root:Copying D:\worksapce\qpetw\data\dbz_2014061316\2014061624.npy to D:\worksapce\qpetw\data\dbz_2014061316_LST\2014061708.npy
# 0
